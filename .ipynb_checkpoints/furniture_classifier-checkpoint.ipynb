# %%
#!pip install gradio
#!pip install -Uqq fastbook

# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd
from fastai.vision.all import *

# %% [markdown]
# # Defining Paths

# %%
r_Dir = 'C:/Users/larsm/PycharmProjects/FurnitureClassifier/data/day-3-kaggle-competition/data_comp/data_comp/'
img_path = os.path.join(r_Dir, 'train' + '/')
test_path = os.path.join(r_Dir, 'test' + '/')

# %% [markdown]
# Lets check how many pictures there is in the training set

# %% [markdown]
# # Training model and Cleaning data

# %%
furnitures = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(224, ResizeMethod.Pad, pad_mode='zeros'),
    batch_tfms=[*aug_transforms()]
)

# %%
dls = furnitures.dataloaders(img_path)
dls.valid.show_batch(max_n=7, nrows=1)

# %% [markdown]
# #### Fine-tuning

# %%
model = vision_learner(dls, resnet18, metrics=error_rate)
model.fine_tune(1)
# Out:
# C:\Users\larsm\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\larsm\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %% [markdown]
# Creating a confusion matrix to vizualize all correct and false predictions of the model

# %% [markdown]
# #### Confusion Matrix

# %%
matrix = ClassificationInterpretation.from_learner(model)
matrix.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
model.export('model.pkl')

# %% [markdown]
# # Making web application interface

# %%
import gradio as gr
import fastai.vision as fv

#function predicts the objects in images
def classify_image(image):
    pred, _, _ = learn.predict(image)
    return str(pred)

learn = load_learner('model.pkl')

#Creating application interface
application = gr.Interface(
    fn=classify_image,
    inputs=gr.inputs.Image(shape=(400, 300), label="Upload an Image"),
    outputs=gr.outputs.Label(label="Predicted Class"),
    title="FastAI Image Classifier",
    description="Classify an image into one of 5 categories of furnitures using FastAI."
)

#Launch web-application
application.launch()
# Out:
# C:\Users\larsm\anaconda3\lib\site-packages\gradio\inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# C:\Users\larsm\anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# C:\Users\larsm\anaconda3\lib\site-packages\gradio\outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# C:\Users\larsm\anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# ...
